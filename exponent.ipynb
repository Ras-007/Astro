# %%
import numpy as np
import pandas as pd
print("Enter no of data points:")
n=int(input())
x=[]
y=[]
for i in range(n):
    a=float((input("enter x value:")))
    b=float((input("enter y value:")))
    x.append(a)
    y.append(b)
df=pd.DataFrame({
    "x":x,
    "y":y
})
df
# Out:
# Enter no of data points:
#       x      y
# 0  61.0  350.0
# 1  26.0  400.0
# 2   7.0  500.0
# 3   2.6  600.0

# %%
import matplotlib.pyplot as plt
plt.scatter(df["x"],df["y"],color="blue")

# %%
Y=np.log10(df['y'])
X=np.log10(df['x'])

# %%
a00=np.sum(X**2)
a01=np.sum(X)
a10=np.sum(X)
a11=n
b0=np.sum(X*Y)
b1=np.sum(Y)

# %%
co_ef_matrix=np.array([[a00,a01],[a10,a11]])
const_matrix=np.array([b0,b1])
co_ef_matrix=np.linalg.inv(co_ef_matrix)
result=np.dot(co_ef_matrix,const_matrix)
result
# Out:
# array([-0.17085543,  2.84633213])

# %%
m=result[0]
c=10**(result[1])
print(m,c)
# Out:
# -0.17085543361871913 701.991947594558

# %%
plt.plot(df["x"],c*df['x']**m,color="red")
plt.scatter(df["x"],df["y"],color="blue")
plt.legend(["Fitted line","Data points"])

# %%
from sklearn.metrics import mean_squared_error,r2_score
y_pred=c*df['x']**m
mse=mean_squared_error(df["y"],y_pred)
mse
# Out:
# 9.043060266301223

# %%
r2=r2_score(df["y"],y_pred)
r2
# Out:
# 0.9990190578694181
